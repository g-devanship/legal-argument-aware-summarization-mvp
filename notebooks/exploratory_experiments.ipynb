# %% [markdown]
# # Exploratory Experiments
#
# This notebook demonstrates the research-grade MVP workflow for legal summarization.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))

from src.pipeline.summarization_pipeline import LegalSummarizationPipeline

pipeline = LegalSummarizationPipeline()

# %%
with open('../data/demo/indian_judgment_sample.txt', 'r', encoding='utf-8') as handle:
    document_text = handle.read()

result = pipeline.summarize_text(document_text, document_id='indian_demo')
result['best_summary']

# %%
import pandas as pd

pd.DataFrame(result['reranking_scores'])

# %%
pd.DataFrame(result['predicted_roles']).head(10)
